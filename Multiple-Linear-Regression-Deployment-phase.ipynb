# %%
# Deployment Phase:

import pickle

# %%
loaded_model=pickle.load(open("finalised_new_model.sav", 'rb'))
result=loaded_model.predict([[65605,153032,107138,0,1]])
# Out:
# C:\ANACONDA\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[100689.01965825]])
