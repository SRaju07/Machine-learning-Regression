# %%
# Deployment Phase:

# pickle is a Python library to save and load Python objects (like models, lists, dictionaries) 

import pickle

# %%
#  Load the Saved new evaluated model to Deployment Phase:

# Load the saved model from the file

# 'rb' - read in binary mode

loaded_model=pickle.load(open("finalized_new_model.sav",'rb'))

# Use the loaded model to predict a value for new data

# [[15]] = input value (1 row, 1 feature)

result=loaded_model.predict([[15]])
# Out:
# C:\ANACONDA\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# result = predicted output

result
# Out:
# array([[166561.06897321]])
